# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.colors as mcolors
import seaborn as sns
sns.set()
import sqlite3

import random

from IPython.display import Image 
from pandas import Series, DataFrame
from matplotlib.pyplot import show,figure,subplot
from matplotlib import dates as dates

# %%
bm = pd.read_csv('data/zippedData/bom.movie_gross.csv.gz')
name = pd.read_csv('data/zippedData/imdb.name.basics.csv.gz')
title_akas = pd.read_csv('data/zippedData/imdb.title.akas.csv.gz')
title_basics = pd.read_csv('data/zippedData/imdb.title.basics.csv.gz')
title_ratings = pd.read_csv('data/zippedData/imdb.title.ratings.csv.gz')
rt_movies = pd.read_csv('data/zippedData/rotten_tomatoes_movies.csv.gz')
tmdb_movies = pd.read_csv('data/zippedData/tmdb.movies.csv.gz')
tn_movie_budgets  = pd.read_csv('data/zippedData/tn.movie_budgets.csv.gz')
ratings = pd.read_csv('data/zippedData/IMDB_ratings.csv.zip')
movies = pd.read_csv('data/zippedData/IMDB_movies.csv.zip')
# Out:
# C:\Users\Lookupkim\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
bm.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
bm.sample(20)
# Out:
#                                            title   studio  domestic_gross  \
# 1532                                     Blended       WB      46300000.0
# 1919                       The Last Witch Hunter     LG/S      27400000.0
# 1416                         The English Teacher    Cdgm.        105000.0
# 2349                             The Conjuring 2  WB (NL)     102500000.0
# 2931                              Paris Can Wait      SPC       5600000.0
# 1636         Island of Lemurs: Madagascar (IMAX)       WB      11300000.0
# 350                                        Rango     Par.     123500000.0
# 352                             The Green Hornet     Sony      98800000.0
# 847   Fetih 1453: The Conquest of Constantinople     NeoC         35700.0
# 3154                                      Widows      Fox      42400000.0
# 783                           The Woman in Black      CBS      54300000.0
# 1163            Hansel and Gretel: Witch Hunters     Par.      55700000.0
# ...

# %%
bm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
duplicates = bm[bm.duplicated()]
print(len(duplicates))
# Out:
# 0

# %%
bm = bm.rename(columns = {'title': 'movie_title'})

# %%
bm.drop(columns='foreign_gross')
# Out:
#                                       movie_title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#       year
# 0     2010
# ...

# %%
title_akas.head()
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %%
title_akas.tail()
# Out:
#          title_id  ordering               title region language        types  \
# 331698  tt9827784         2  Sayonara kuchibiru    NaN      NaN     original
# 331699  tt9827784         3       Farewell Song    XWW       en  imdbDisplay
# 331700  tt9880178         1         La atención    NaN      NaN     original
# 331701  tt9880178         2         La atención     ES      NaN          NaN
# 331702  tt9880178         3       The Attention    XWW       en  imdbDisplay
#
#        attributes  is_original_title
# 331698        NaN                1.0
# 331699        NaN                0.0
# 331700        NaN                1.0
# 331701        NaN                0.0
# 331702        NaN                0.0

# %%
title_akas.sample(20)
# Out:
#           title_id  ordering                                       title  \
# 69143    tt2048837         3                       Pura vida - The Ridge
# 111636   tt1588173        31                       Mi novio es un zombie
# 63091    tt1757919         1        Un cine como tú en un país como éste
# 270583   tt5741848         2                                      Kashin
# 117193   tt1732617         1                  Disabled But Able to Rock!
# 269280   tt8182884         2                              The Enthusiasm
# 167344   tt3784566         3                                 Poarta Albã
# 130046  tt10219146         1                       Жилище в горах Фучунь
# 42332    tt1966604        16                                 El impostor
# 280198   tt4016226         2  The Resurrection of Jake The Snake Roberts
# 291790   tt4746484         6                            Rég nem szerelem
# 134973   tt2638480         5               Land Without Evil: Ivy Maraey
# ...

# %%
title_akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   title_id           331703 non-null  object
#  1   ordering           331703 non-null  int64
#  2   title              331703 non-null  object
#  3   region             278410 non-null  object
#  4   language           41715 non-null   object
#  5   types              168447 non-null  object
#  6   attributes         14925 non-null   object
#  7   is_original_title  331678 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 20.2+ MB

# %%
title_akas.isnull().any()
# Out:
# title_id             False
# ordering             False
# title                False
# region                True
# language              True
# types                 True
# attributes            True
# is_original_title     True
# dtype: bool

# %%
title_akas.isnull().sum()
# Out:
# title_id                  0
# ordering                  0
# title                     0
# region                53293
# language             289988
# types                163256
# attributes           316778
# is_original_title        25
# dtype: int64

# %%
shape = title_akas.shape
print(shape)
# Out:
# (331703, 8)

# %%
bool_series = pd.notnull(title_akas["language"])
title_akas[bool_series]
# Out:
#          title_id  ordering                          title region language  \
# 0       tt0369610        10                  Джурасик свят     BG       bg
# 8       tt0369610        18                   Olam ha'Yura     IL       he
# 19      tt0369610        28               Monde jurassique     CA       fr
# 27      tt0369610        35                Jurassic Park 4     TR       tr
# 36      tt0369610        43                 Jurassic World     TR       tr
# ...           ...       ...                            ...    ...      ...
# 331683  tt9657946         1                         Homing    XWW       en
# 331691  tt9726638         1             Qi Tian Da Sheng 2     CN      yue
# 331693  tt9726638         3  Qi Tian Da Sheng Huo Yan Shan     CN      yue
# 331699  tt9827784         3                  Farewell Song    XWW       en
# 331702  tt9880178         3                  The Attention    XWW       en
#
#               types                  attributes  is_original_title
# ...

# %%
title_akas = title_akas.rename(columns = {'title': 'movie_title'})

# %%
title_akas_2 = title_akas.drop(['language', 'types', 'attributes'], axis=1)

# %%
title_akas_2.sample(20)
# Out:
#          title_id  ordering                             movie_title region  \
# 146607  tt1298650        38  Kariibi mere piraadid: Võõrastel vetel     EE
# 43879   tt1754656        13                       Den lille prinsen     FI
# 309426  tt4598764         2                                     Ney     AR
# 16231   tt2466086         3                           Über das Meer     DE
# 88159   tt2369333         5                                 Student     RS
# 65192   tt1590193         9                             El pasajero     MX
# 45653   tt2817128         1                                   Cathy     US
# 11547   tt1650453         9       Untitled Hirokazu Koreeda Project     JP
# 10250   tt2208538         1                                    Evil    NaN
# 126937  tt3626436         3                           Mundo Mutante     PT
# 192688  tt3623924         1                 THIRST: Mission Liberia     US
# ...

# %%
title_akas_2.isnull().sum()
# Out:
# title_id                 0
# ordering                 0
# movie_title              0
# region               53293
# is_original_title       25
# dtype: int64

# %%
title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
title_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
rt_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17712 entries, 0 to 17711
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   rotten_tomatoes_link              17712 non-null  object
#  1   movie_title                       17712 non-null  object
#  2   movie_info                        17391 non-null  object
#  3   critics_consensus                 9134 non-null   object
#  4   content_rating                    17712 non-null  object
#  5   genres                            17693 non-null  object
#  6   directors                         17518 non-null  object
#  7   authors                           16170 non-null  object
#  8   actors                            17360 non-null  object
#  9   original_release_date             16546 non-null  object
#  10  streaming_release_date            17328 non-null  object
# ...

# %%
rt_movies.head()
# Out:
#                     rotten_tomatoes_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  Always trouble-prone, the life of teenager Per...
# 1  Kate (Catherine Keener) and her husband Alex (...
# 2  A successful, middle-aged Hollywood songwriter...
# 3  Following the closing arguments in a murder tr...
# 4  In 1866, Professor Pierre M. Aronnax (Paul Luk...
#
# ...

# %%
tmdb_movies.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# ...

# %%
tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
ratings.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
# 2     tt0001892                    5.8          188        6.0          6.0
# 3     tt0002101                    5.2          446        5.3          5.0
# 4     tt0002130                    7.0         2237        6.9          7.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
# 1        57       18       58      137      139  ...                     6.2
# 2         6        6       17       44       52  ...                     5.8
# 3        15        8       16       62       98  ...                     5.5
# 4       210      225      436      641      344  ...                     7.3
#
# ...

# %%
data['imdb.name.basics.csv.gz']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-1518f6176862> in <module>
# ----> 1 data['imdb.name.basics.csv.gz']
#
# NameError: name 'data' is not defined

# %%
df = data['imdb.name.basics.csv.gz']
np.round(df.describe())

# %%
df = data['imdb.name.basics.csv.gz']
df.shape

# %%
df = data['imdb.name.basics.csv.gz']
df.isnull().any()

# %%
df = data['imdb.name.basics.csv.gz']
df.isnull().sum()

# %%
df = data['imdb.name.basics.csv.gz']
np.round(df.describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8cc36ec6aabb> in <module>
# ----> 1 df = data['imdb.name.basics.csv.gz']
#       2 np.round(df.describe())
#
# NameError: name 'data' is not defined

# %%
df = data['imdb.name.basics.csv.gz']
df.shape

# %%
df = data['imdb.name.basics.csv.gz']
df.isnull().any()

# %%
df = data['imdb.name.basics.csv.gz']
df.isnull().sum()

# %%
df = data['imdb.name.basics.csv.gz']
df.head()

# %%
df = data['imdb.name.basics.csv.gz']
df.tail()

# %%
df = data['imdb.name.basics.csv.gz']
df.sample(20)

# %%
df = data['imdb.name.basics.csv.gz']
df.info()

# %%
df = data['imdb.name.basics.csv.gz']
np.round(df.describe())

# %%
df = data['imdb.name.basics.csv.gz']
df.shape

# %%
df = data['imdb.name.basics.csv.gz']
df.isnull().any()

# %%
df = data['imdb.name.basics.csv.gz']
df.isnull().sum()

# %%
data['imdb.title.principals.csv.gz']

# %%
df = data['imdb.title.principals.csv.gz']
df.head()

# %%
df = data['imdb.title.principals.csv.gz']
df.tail()

# %%
df = data['imdb.title.principals.csv.gz']
df.sample(20)

# %%
df = data['imdb.title.principals.csv.gz']
df.info()

# %%
df = data['imdb.title.principals.csv.gz']
np.round(df.describe())

# %%
df = data['imdb.title.principals.csv.gz']
df.shape

# %%
df = data['imdb.title.principals.csv.gz']
df.isnull().any()

# %%
df = data['imdb.title.principals.csv.gz']
df.isnull().sum()

# %%
data['imdb.title.crew.csv.gz']

# %%
df = data['imdb.title.crew.csv.gz']
df.head()

# %%
df = data['imdb.title.crew.csv.gz']
df.tail()

# %%
df = data['imdb.title.crew.csv.gz']
df.sample(20)

# %%
df = data['imdb.title.crew.csv.gz']
df.info()

# %%
df = data['imdb.title.crew.csv.gz']
np.round(df.describe())

# %%
df = data['imdb.title.crew.csv.gz']
df.shape

# %%
df = data['imdb.title.crew.csv.gz']
df.isnull().any()

# %%
data['rotten_tomatoes_critic_reviews.csv.gz']

# %%
df = data['rotten_tomatoes_critic_reviews.csv.gz']
df.head()

# %%
df = data['rotten_tomatoes_critic_reviews.csv.gz']
df.tail()

# %%
df = data['rotten_tomatoes_critic_reviews.csv.gz']
df.sample(20)

# %%
df = data['rotten_tomatoes_critic_reviews.csv.gz']
df.info()

# %%
df = data['rotten_tomatoes_critic_reviews.csv.gz']
np.round(df.describe())

# %%
df = data['rotten_tomatoes_critic_reviews.csv.gz']
df.shape

# %%
df = data['rotten_tomatoes_critic_reviews.csv.gz']
df.isnull().any()

# %%
df = data['rotten_tomatoes_critic_reviews.csv.gz']
df.isnull().sum()
